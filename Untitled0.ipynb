# %% [markdown]
# QUES 1. What is the purpose of a PivotTable in Excel?
# -  A PivotTable is used to summarize, analyze, and organize large amounts of data quickly and easily.
#
# QUES 2.Explain the difference between Sorting and Filtering with an example from this dataset.
# - Sorting means Arranging data in a specific order (A–Z, Z–A, Smallest to Largest, etc.).
# Example we sort a salary from lowest to highest.
# The order of rows changes, but all data remains visible.
# - Filtering means Showing only selected data and hiding the rest.
#  Example- If we filter department = sales
#  it will display only sales employee...
#
#  Ques 7. Why are Dashboards important for decision-making in business analysis?
#  -  Dashboards are important because they visually summarize key business data, helping managers monitor performance, identify trends, and make faster and better decisions.
#  1. Quick overview of performance
#  2. Better data visualization
#  3. Faster dicision making
#  4. Real time monitoring
#  5. Identifying problems early
